# %% [markdown]
# # Lab - Regressao
#
# * Utilizando um datset fornecido, contendo dados sobre suicídios, implemente o que se pede.
#
# * Reponda as questões do Quiz sobre os resultados obtidos neste Lab e envie o formulário.
#
# * Envie/devolva o seu notebook contendo suas implementações.

# %% [markdown]
# ## Dados do(a) aluno(a)
#
# **Nome**: Gabriel Paiva Medeiros
#
# **Matrícula**: 118210822

# %% [markdown]
# ## Imports.

# %%
import requests
from io import StringIO

import os
import warnings
warnings.filterwarnings('ignore')

import numpy as np 
import pandas as pd 

from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %% [markdown]
# ## Carregando o Datset Original

# %%
orig_url='https://drive.google.com/file/d/1bLL16sPoEUOAl0_-ED6kQNoiFm8XQh2A/view?usp=sharing'
file_id = orig_url.split('/')[-2]
dwn_url='https://drive.google.com/uc?export=download&id=' + file_id
url = requests.get(dwn_url).text
csv_raw = StringIO(url)
data = pd.read_csv(csv_raw, encoding = "ISO-8859-1")

data.head()
# Out:
#   ï»¿country  year     sex          age  suicides_no  population  \
# 0    Albania  1987    male  15-24 years           21      312900
# 1    Albania  1987    male  35-54 years           16      308000
# 2    Albania  1987  female  15-24 years           14      289700
# 3    Albania  1987    male    75+ years            1       21800
# 4    Albania  1987    male  25-34 years            9      274300
#
#    suicides/100k pop country-year  HDI for year  gdp_for_year ($)   \
# 0               6.71  Albania1987           NaN      2,156,624,900
# 1               5.19  Albania1987           NaN      2,156,624,900
# 2               4.83  Albania1987           NaN      2,156,624,900
# 3               4.59  Albania1987           NaN      2,156,624,900
# 4               3.28  Albania1987           NaN      2,156,624,900
#
#    gdp_per_capita ($)       generation
# 0                 796     Generation X
# 1                 796           Silent
# 2                 796     Generation X
# 3                 796  G.I. Generation
# 4                 796          Boomers

# %% [markdown]
# Usando sklearn, implemente uma **Regressão Linear Simples** para analisar se o número de suicídios (`'suicides_no'`) pode ser parcialmente explicado com base na população (`'population'`).

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

X_1 = data['population'].values.reshape(-1, 1)
y_1 = data['suicides_no'].values

est = LinearRegression()
est.fit(X_1, y_1)

y_pred_1 = est.predict(X_1)

print('MAE:', mean_absolute_error(y_1, y_pred_1))
print('MSE:', mean_squared_error(y_1, y_pred_1))
print('RMSE: ', mean_squared_error(y_1, y_pred_1,squared=False))
print("O coeficiente b0 eh:   {}".format(est.intercept_))
print("O coeficiente b1 eh:   {}".format(est.coef_[0]))
# Out:
# MAE: 217.0399022781815
# MSE: 504749.8897745603
# RMSE:  710.4575214427392
# O coeficiente b0 eh:   -19.544371255741993
# O coeficiente b1 eh:   0.00014208569223424667

# %% [markdown]
# Agora implemente uma **Regressão Linear Múltipla** para analisar se o número de suicídios (`'suicides_no'`) pode ser parcialmente explicado com base na combinação dos valores de população (`'population'`) e renda per capta (`'gdp_per_capita ($)'`).

# %%
X_2 = data[['population', 'gdp_per_capita ($)']].values.reshape(-1, 2)
y_2 = data['suicides_no'].values

est = LinearRegression()
est.fit(X_2, y_2)

y_pred_2 = est.predict(X_2)

print('MAE:', mean_absolute_error(y_2, y_pred_2))
print('MSE:', mean_squared_error(y_2, y_pred_2))
print('RMSE: ', mean_squared_error(y_2, y_pred_2,squared=False))
print("O coeficiente b0 eh:   {}".format(est.intercept_))
print("O coeficiente b1 eh:   {}".format(est.coef_[0]))
# Out:
# MAE: 217.4973971637211
# MSE: 504648.85075191973
# RMSE:  710.386409464539
# O coeficiente b0 eh:   -28.16300908374197
# O coeficiente b1 eh:   0.00014187553920198405

# %% [markdown]
# Verifique se houve aumento/diminuição no coeficiente de determinação de um cenário para o outro.

# %%
print('First Case - r2_score: ', r2_score(y_1, y_pred_1))
print('Second Case - r2_score: ', r2_score(y_2, y_pred_2))
# Out:
# First Case - r2_score:  0.3796559399177645
# Second Case - r2_score:  0.37978011816683666
